# %%
import os
import cv2
import torch
import numpy as np
from torchvision import models, transforms
from PIL import Image
from sklearn.cluster import KMeans
import random

# %%
resnet = models.resnet50(pretrained=True)
resnet = torch.nn.Sequential(*list(resnet.children())[:-1])  
resnet.eval()
# Out:
# c:\Users\KIIT\anaconda3\envs\video\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\KIIT\anaconda3\envs\video\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (5): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (6): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (7): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
def extract_features(video_path, sample_rate):
    cap = cv2.VideoCapture(video_path)
    features, frames = [], []
    idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if idx % sample_rate == 0:  
            rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            img = Image.fromarray(rgb)
            tensor = transform(img).unsqueeze(0)  # [1,3,224,224]

            with torch.no_grad():
                feat = resnet(tensor)  # [1,2048,1,1]
                feat = feat.squeeze().cpu().numpy()
            features.append(feat)
            frames.append(frame)
        idx += 1
    cap.release()
    return np.array(features), frames

# %%
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema

def extract_keyframes_from_frames(frames, step=10):
    """
    Extract keyframes from a list of frames using motion-based key moment detection.
    Parameters:
        frames (list): List of consecutive video frames (as numpy arrays).
        step (int): Process every nth frame for speed.
    Returns:
        keyframes (list): List of selected keyframes.
        key_indices (list): Frame indices of selected keyframes.
    """

    if len(frames) < 2:
        print("Not enough frames for motion analysis.")
        return [], []

    prev_gray = cv2.cvtColor(frames[0], cv2.COLOR_BGR2GRAY)
    pdm_values = []
    processed_frames = []
    idx = 0

    for frame in frames[1:]:
        if idx % step != 0:
            idx += 1
            continue

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Optical flow (motion vectors between frames)
        flow = cv2.calcOpticalFlowFarneback(prev_gray, gray, None,
                                            0.5, 3, 15, 3, 5, 1.2, 0)

        mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
        AM = np.mean(mag) + 1e-6  # average movement

        # Direction bins (8 bins of 45° each)
        bins = np.zeros(8)
        bin_indices = np.floor(ang * 8 / (2 * np.pi)).astype(int) % 8
        for b in range(8):
            bins[b] = np.sum(mag[bin_indices == b])

        # Perceived Dominant Movement (PDM)
        PDM = np.max(bins) / AM
        pdm_values.append(PDM)
        processed_frames.append((idx, frame))

        prev_gray = gray
        idx += 1

    # Convert to numpy for easier math
    pdm_arr = np.array(pdm_values)

    # Find local maxima & minima
    maxima = argrelextrema(pdm_arr, np.greater)[0]
    minima = argrelextrema(pdm_arr, np.less)[0]

    keyframes = []
    key_indices = []

    # Extract key moments (maxima between minima)
    for i in range(len(minima) - 1):
        seg_min1, seg_min2 = minima[i], minima[i + 1]
        seg_max = [m for m in maxima if seg_min1 < m < seg_min2]
        if seg_max:  # if maxima exists between minima
            best_idx = seg_max[np.argmax(pdm_arr[seg_max])]
            frame_no, key_frame = processed_frames[best_idx]
            keyframes.append(key_frame)
            key_indices.append(frame_no)

    return keyframes, key_indices

# %%
video_folder = "videos/"
output_root = "keyframes1/"
os.makedirs(output_root, exist_ok=True)

# %%
video_files = [f for f in os.listdir(video_folder) if f.endswith((".mp4", ".avi", ".mov"))]

for n,video_file in enumerate(video_files):
    video_path = os.path.join(video_folder, video_file)
    print(f"Processing {video_file}...")

    
    features, frames = extract_features(video_path, sample_rate=10)
    if len(frames) == 0:
        print(f"⚠️ Skipped {video_file} (too short)")
        continue

    # K = int(random.uniform(0.05,0.15) * len(frames))
    keyframes, indices = extract_keyframes_from_frames(frames)

    
    base_name = str(n+1)
    out_dir = os.path.join(output_root, base_name)
    os.makedirs(out_dir, exist_ok=True)

    
    for i, (frame, idx) in enumerate(zip(keyframes, indices)):
        out_path = os.path.join(out_dir, f"keyframe_{i+1}_frame{idx}.jpg")
        cv2.imwrite(out_path, frame)
        print(f"Saved {out_path}")

   
    txt_path = os.path.join(out_dir, f"{n+1}.txt")
    with open(txt_path, "w") as f:
        for idx in indices:
            f.write(str(idx) + "\n")

    print(f"Saved indices to {txt_path}")
# Out:
# Processing Air_Force_One.mp4...
# Saved keyframes1/1\keyframe_1_frame30.jpg
# Saved keyframes1/1\keyframe_2_frame90.jpg
# Saved keyframes1/1\keyframe_3_frame120.jpg
# Saved keyframes1/1\keyframe_4_frame140.jpg
# Saved keyframes1/1\keyframe_5_frame160.jpg
# Saved keyframes1/1\keyframe_6_frame200.jpg
# Saved keyframes1/1\keyframe_7_frame220.jpg
# Saved keyframes1/1\keyframe_8_frame250.jpg
# Saved keyframes1/1\keyframe_9_frame270.jpg
# Saved keyframes1/1\keyframe_10_frame310.jpg
# Saved keyframes1/1\keyframe_11_frame330.jpg
# Saved keyframes1/1\keyframe_12_frame360.jpg
# Saved keyframes1/1\keyframe_13_frame390.jpg
# Saved indices to keyframes1/1\1.txt
# Processing Base jumping.mp4...
# Saved keyframes1/2\keyframe_1_frame40.jpg
# Saved keyframes1/2\keyframe_2_frame70.jpg
# Saved keyframes1/2\keyframe_3_frame100.jpg
# Saved keyframes1/2\keyframe_4_frame130.jpg
# Saved keyframes1/2\keyframe_5_frame170.jpg
# Saved keyframes1/2\keyframe_6_frame200.jpg
# Saved keyframes1/2\keyframe_7_frame240.jpg
# Saved keyframes1/2\keyframe_8_frame280.jpg
# Saved keyframes1/2\keyframe_9_frame320.jpg
# Saved keyframes1/2\keyframe_10_frame340.jpg
# Saved keyframes1/2\keyframe_11_frame380.jpg
# Saved keyframes1/2\keyframe_12_frame410.jpg
# Saved keyframes1/2\keyframe_13_frame430.jpg
# Saved keyframes1/2\keyframe_14_frame450.jpg
# Saved indices to keyframes1/2\2.txt
# Processing Bearpark_climbing.mp4...
# Saved keyframes1/3\keyframe_1_frame30.jpg
# Saved keyframes1/3\keyframe_2_frame50.jpg
# Saved keyframes1/3\keyframe_3_frame70.jpg
# Saved keyframes1/3\keyframe_4_frame100.jpg
# Saved keyframes1/3\keyframe_5_frame130.jpg
# Saved keyframes1/3\keyframe_6_frame160.jpg
# Saved keyframes1/3\keyframe_7_frame210.jpg
# Saved keyframes1/3\keyframe_8_frame250.jpg
# Saved keyframes1/3\keyframe_9_frame270.jpg
# Saved keyframes1/3\keyframe_10_frame290.jpg
# Saved indices to keyframes1/3\3.txt
# Processing Bike Polo.mp4...
# Saved keyframes1/4\keyframe_1_frame30.jpg
# Saved keyframes1/4\keyframe_2_frame50.jpg
# Saved keyframes1/4\keyframe_3_frame100.jpg
# Saved keyframes1/4\keyframe_4_frame120.jpg
# Saved keyframes1/4\keyframe_5_frame150.jpg
# Saved keyframes1/4\keyframe_6_frame200.jpg
# Saved keyframes1/4\keyframe_7_frame230.jpg
# Saved keyframes1/4\keyframe_8_frame270.jpg
# Saved indices to keyframes1/4\4.txt
# Processing Bus_in_Rock_Tunnel.mp4...
# Saved keyframes1/5\keyframe_1_frame20.jpg
# Saved keyframes1/5\keyframe_2_frame40.jpg
# Saved keyframes1/5\keyframe_3_frame60.jpg
# Saved keyframes1/5\keyframe_4_frame80.jpg
# Saved keyframes1/5\keyframe_5_frame100.jpg
# Saved keyframes1/5\keyframe_6_frame140.jpg
# Saved keyframes1/5\keyframe_7_frame180.jpg
# Saved keyframes1/5\keyframe_8_frame210.jpg
# Saved keyframes1/5\keyframe_9_frame230.jpg
# Saved keyframes1/5\keyframe_10_frame260.jpg
# Saved keyframes1/5\keyframe_11_frame290.jpg
# Saved keyframes1/5\keyframe_12_frame320.jpg
# Saved keyframes1/5\keyframe_13_frame360.jpg
# Saved keyframes1/5\keyframe_14_frame380.jpg
# Saved keyframes1/5\keyframe_15_frame400.jpg
# Saved keyframes1/5\keyframe_16_frame430.jpg
# Saved indices to keyframes1/5\5.txt
# Processing car_over_camera.mp4...
# Saved keyframes1/6\keyframe_1_frame50.jpg
# Saved keyframes1/6\keyframe_2_frame80.jpg
# Saved keyframes1/6\keyframe_3_frame110.jpg
# Saved keyframes1/6\keyframe_4_frame150.jpg
# Saved keyframes1/6\keyframe_5_frame170.jpg
# Saved keyframes1/6\keyframe_6_frame200.jpg
# Saved keyframes1/6\keyframe_7_frame250.jpg
# Saved keyframes1/6\keyframe_8_frame290.jpg
# Saved keyframes1/6\keyframe_9_frame310.jpg
# Saved keyframes1/6\keyframe_10_frame330.jpg
# Saved keyframes1/6\keyframe_11_frame370.jpg
# Saved keyframes1/6\keyframe_12_frame400.jpg
# Saved indices to keyframes1/6\6.txt
# Processing Car_railcrossing.mp4...
# Saved keyframes1/7\keyframe_1_frame20.jpg
# Saved keyframes1/7\keyframe_2_frame40.jpg
# Saved keyframes1/7\keyframe_3_frame70.jpg
# Saved keyframes1/7\keyframe_4_frame110.jpg
# Saved keyframes1/7\keyframe_5_frame130.jpg
# Saved keyframes1/7\keyframe_6_frame150.jpg
# Saved keyframes1/7\keyframe_7_frame180.jpg
# Saved keyframes1/7\keyframe_8_frame200.jpg
# Saved keyframes1/7\keyframe_9_frame260.jpg
# Saved keyframes1/7\keyframe_10_frame290.jpg
# Saved keyframes1/7\keyframe_11_frame320.jpg
# Saved keyframes1/7\keyframe_12_frame350.jpg
# Saved keyframes1/7\keyframe_13_frame380.jpg
# Saved keyframes1/7\keyframe_14_frame400.jpg
# Saved keyframes1/7\keyframe_15_frame420.jpg
# Saved indices to keyframes1/7\7.txt
# Processing Cockpit_Landing.mp4...
# Saved keyframes1/8\keyframe_1_frame30.jpg
# Saved keyframes1/8\keyframe_2_frame50.jpg
# Saved keyframes1/8\keyframe_3_frame80.jpg
# Saved keyframes1/8\keyframe_4_frame130.jpg
# Saved keyframes1/8\keyframe_5_frame150.jpg
# Saved keyframes1/8\keyframe_6_frame210.jpg
# Saved keyframes1/8\keyframe_7_frame230.jpg
# Saved keyframes1/8\keyframe_8_frame270.jpg
# Saved keyframes1/8\keyframe_9_frame290.jpg
# Saved keyframes1/8\keyframe_10_frame330.jpg
# Saved keyframes1/8\keyframe_11_frame350.jpg
# Saved keyframes1/8\keyframe_12_frame370.jpg
# Saved keyframes1/8\keyframe_13_frame400.jpg
# Saved keyframes1/8\keyframe_14_frame450.jpg
# Saved keyframes1/8\keyframe_15_frame470.jpg
# Saved keyframes1/8\keyframe_16_frame490.jpg
# Saved keyframes1/8\keyframe_17_frame510.jpg
# Saved keyframes1/8\keyframe_18_frame530.jpg
# Saved keyframes1/8\keyframe_19_frame550.jpg
# Saved keyframes1/8\keyframe_20_frame620.jpg
# Saved keyframes1/8\keyframe_21_frame650.jpg
# Saved keyframes1/8\keyframe_22_frame690.jpg
# Saved keyframes1/8\keyframe_23_frame730.jpg
# Saved keyframes1/8\keyframe_24_frame750.jpg
# Saved keyframes1/8\keyframe_25_frame770.jpg
# Saved keyframes1/8\keyframe_26_frame800.jpg
# Saved keyframes1/8\keyframe_27_frame820.jpg
# Saved keyframes1/8\keyframe_28_frame840.jpg
# Saved keyframes1/8\keyframe_29_frame860.jpg
# Saved indices to keyframes1/8\8.txt
# Processing Cooking.mp4...
# Saved keyframes1/9\keyframe_1_frame30.jpg
# Saved keyframes1/9\keyframe_2_frame60.jpg
# Saved keyframes1/9\keyframe_3_frame80.jpg
# Saved indices to keyframes1/9\9.txt
# Processing Eiffel Tower.mp4...
# Saved keyframes1/10\keyframe_1_frame50.jpg
# Saved keyframes1/10\keyframe_2_frame80.jpg
# Saved keyframes1/10\keyframe_3_frame100.jpg
# Saved keyframes1/10\keyframe_4_frame120.jpg
# Saved keyframes1/10\keyframe_5_frame160.jpg
# Saved keyframes1/10\keyframe_6_frame220.jpg
# Saved keyframes1/10\keyframe_7_frame290.jpg
# Saved keyframes1/10\keyframe_8_frame310.jpg
# Saved keyframes1/10\keyframe_9_frame330.jpg
# Saved keyframes1/10\keyframe_10_frame350.jpg
# Saved keyframes1/10\keyframe_11_frame400.jpg
# Saved keyframes1/10\keyframe_12_frame430.jpg
# Saved keyframes1/10\keyframe_13_frame460.jpg
# Saved indices to keyframes1/10\10.txt
# Processing Excavators river crossing.mp4...
# Saved keyframes1/11\keyframe_1_frame40.jpg
# Saved keyframes1/11\keyframe_2_frame70.jpg
# Saved keyframes1/11\keyframe_3_frame110.jpg
# Saved keyframes1/11\keyframe_4_frame140.jpg
# Saved keyframes1/11\keyframe_5_frame170.jpg
# Saved keyframes1/11\keyframe_6_frame210.jpg
# Saved keyframes1/11\keyframe_7_frame250.jpg
# Saved keyframes1/11\keyframe_8_frame290.jpg
# Saved keyframes1/11\keyframe_9_frame310.jpg
# Saved keyframes1/11\keyframe_10_frame330.jpg
# Saved keyframes1/11\keyframe_11_frame350.jpg
# Saved keyframes1/11\keyframe_12_frame370.jpg
# Saved keyframes1/11\keyframe_13_frame410.jpg
# Saved keyframes1/11\keyframe_14_frame430.jpg
# Saved keyframes1/11\keyframe_15_frame450.jpg
# Saved keyframes1/11\keyframe_16_frame480.jpg
# Saved keyframes1/11\keyframe_17_frame500.jpg
# Saved keyframes1/11\keyframe_18_frame520.jpg
# Saved keyframes1/11\keyframe_19_frame570.jpg
# Saved keyframes1/11\keyframe_20_frame600.jpg
# Saved keyframes1/11\keyframe_21_frame640.jpg
# Saved keyframes1/11\keyframe_22_frame660.jpg
# Saved keyframes1/11\keyframe_23_frame690.jpg
# Saved keyframes1/11\keyframe_24_frame710.jpg
# Saved keyframes1/11\keyframe_25_frame730.jpg
# Saved keyframes1/11\keyframe_26_frame760.jpg
# Saved keyframes1/11\keyframe_27_frame790.jpg
# Saved keyframes1/11\keyframe_28_frame820.jpg
# Saved keyframes1/11\keyframe_29_frame850.jpg
# Saved keyframes1/11\keyframe_30_frame880.jpg
# Saved keyframes1/11\keyframe_31_frame910.jpg
# Saved indices to keyframes1/11\11.txt
# Processing Fire Domino.mp4...
# Saved keyframes1/12\keyframe_1_frame50.jpg
# Saved keyframes1/12\keyframe_2_frame80.jpg
# Saved keyframes1/12\keyframe_3_frame120.jpg
# Saved keyframes1/12\keyframe_4_frame140.jpg
# Saved indices to keyframes1/12\12.txt
# Processing Jumps.mp4...
# Saved keyframes1/13\keyframe_1_frame30.jpg
# Saved indices to keyframes1/13\13.txt
# Processing Kids_playing_in_leaves.mp4...
# Saved keyframes1/14\keyframe_1_frame20.jpg
# Saved keyframes1/14\keyframe_2_frame40.jpg
# Saved keyframes1/14\keyframe_3_frame60.jpg
# Saved keyframes1/14\keyframe_4_frame80.jpg
# Saved keyframes1/14\keyframe_5_frame100.jpg
# Saved keyframes1/14\keyframe_6_frame130.jpg
# Saved keyframes1/14\keyframe_7_frame160.jpg
# Saved keyframes1/14\keyframe_8_frame180.jpg
# Saved keyframes1/14\keyframe_9_frame200.jpg
# Saved keyframes1/14\keyframe_10_frame230.jpg
# Saved keyframes1/14\keyframe_11_frame270.jpg
# Saved indices to keyframes1/14\14.txt
# Processing Notre_Dame.mp4...
# Saved keyframes1/15\keyframe_1_frame50.jpg
# Saved keyframes1/15\keyframe_2_frame90.jpg
# Saved keyframes1/15\keyframe_3_frame110.jpg
# Saved keyframes1/15\keyframe_4_frame150.jpg
# Saved keyframes1/15\keyframe_5_frame180.jpg
# Saved keyframes1/15\keyframe_6_frame210.jpg
# Saved keyframes1/15\keyframe_7_frame250.jpg
# Saved keyframes1/15\keyframe_8_frame270.jpg
# Saved keyframes1/15\keyframe_9_frame290.jpg
# Saved keyframes1/15\keyframe_10_frame330.jpg
# Saved keyframes1/15\keyframe_11_frame360.jpg
# Saved keyframes1/15\keyframe_12_frame380.jpg
# Saved indices to keyframes1/15\15.txt
# Processing Paintball.mp4...
# Saved keyframes1/16\keyframe_1_frame30.jpg
# Saved keyframes1/16\keyframe_2_frame50.jpg
# Saved keyframes1/16\keyframe_3_frame80.jpg
# Saved keyframes1/16\keyframe_4_frame140.jpg
# Saved keyframes1/16\keyframe_5_frame160.jpg
# Saved keyframes1/16\keyframe_6_frame220.jpg
# Saved keyframes1/16\keyframe_7_frame240.jpg
# Saved keyframes1/16\keyframe_8_frame280.jpg
# Saved keyframes1/16\keyframe_9_frame300.jpg
# Saved keyframes1/16\keyframe_10_frame330.jpg
# Saved keyframes1/16\keyframe_11_frame360.jpg
# Saved keyframes1/16\keyframe_12_frame390.jpg
# Saved keyframes1/16\keyframe_13_frame420.jpg
# Saved keyframes1/16\keyframe_14_frame440.jpg
# Saved keyframes1/16\keyframe_15_frame490.jpg
# Saved keyframes1/16\keyframe_16_frame540.jpg
# Saved keyframes1/16\keyframe_17_frame560.jpg
# Saved indices to keyframes1/16\16.txt
# Processing paluma_jump.mp4...
# Saved keyframes1/17\keyframe_1_frame30.jpg
# Saved keyframes1/17\keyframe_2_frame70.jpg
# Saved keyframes1/17\keyframe_3_frame110.jpg
# Saved keyframes1/17\keyframe_4_frame140.jpg
# Saved keyframes1/17\keyframe_5_frame170.jpg
# Saved keyframes1/17\keyframe_6_frame200.jpg
# Saved keyframes1/17\keyframe_7_frame220.jpg
# Saved indices to keyframes1/17\17.txt
# Processing playing_ball.mp4...
# Saved keyframes1/18\keyframe_1_frame40.jpg
# Saved keyframes1/18\keyframe_2_frame90.jpg
# Saved keyframes1/18\keyframe_3_frame120.jpg
# Saved keyframes1/18\keyframe_4_frame170.jpg
# Saved keyframes1/18\keyframe_5_frame190.jpg
# Saved keyframes1/18\keyframe_6_frame210.jpg
# Saved keyframes1/18\keyframe_7_frame250.jpg
# Saved keyframes1/18\keyframe_8_frame280.jpg
# Saved indices to keyframes1/18\18.txt
# Processing Playing_on_water_slide.mp4...
# Saved keyframes1/19\keyframe_1_frame30.jpg
# Saved keyframes1/19\keyframe_2_frame60.jpg
# Saved keyframes1/19\keyframe_3_frame110.jpg
# Saved keyframes1/19\keyframe_4_frame130.jpg
# Saved keyframes1/19\keyframe_5_frame150.jpg
# Saved keyframes1/19\keyframe_6_frame180.jpg
# Saved keyframes1/19\keyframe_7_frame200.jpg
# Saved keyframes1/19\keyframe_8_frame230.jpg
# Saved keyframes1/19\keyframe_9_frame250.jpg
# Saved keyframes1/19\keyframe_10_frame270.jpg
# Saved indices to keyframes1/19\19.txt
# Processing Saving dolphines.mp4...
# Saved keyframes1/20\keyframe_1_frame30.jpg
# Saved keyframes1/20\keyframe_2_frame50.jpg
# Saved keyframes1/20\keyframe_3_frame100.jpg
# Saved keyframes1/20\keyframe_4_frame120.jpg
# Saved keyframes1/20\keyframe_5_frame160.jpg
# Saved keyframes1/20\keyframe_6_frame190.jpg
# Saved keyframes1/20\keyframe_7_frame220.jpg
# Saved keyframes1/20\keyframe_8_frame240.jpg
# Saved keyframes1/20\keyframe_9_frame260.jpg
# Saved keyframes1/20\keyframe_10_frame290.jpg
# Saved keyframes1/20\keyframe_11_frame320.jpg
# Saved keyframes1/20\keyframe_12_frame350.jpg
# Saved keyframes1/20\keyframe_13_frame390.jpg
# Saved keyframes1/20\keyframe_14_frame410.jpg
# Saved keyframes1/20\keyframe_15_frame450.jpg
# Saved keyframes1/20\keyframe_16_frame480.jpg
# Saved keyframes1/20\keyframe_17_frame540.jpg
# Saved keyframes1/20\keyframe_18_frame600.jpg
# Saved keyframes1/20\keyframe_19_frame620.jpg
# Saved indices to keyframes1/20\20.txt
# Processing Scuba.mp4...
# Saved keyframes1/21\keyframe_1_frame20.jpg
# Saved keyframes1/21\keyframe_2_frame40.jpg
# Saved keyframes1/21\keyframe_3_frame70.jpg
# Saved keyframes1/21\keyframe_4_frame100.jpg
# Saved keyframes1/21\keyframe_5_frame130.jpg
# Saved keyframes1/21\keyframe_6_frame160.jpg
# Saved keyframes1/21\keyframe_7_frame180.jpg
# Saved indices to keyframes1/21\21.txt
# Processing St Maarten Landing.mp4...
# Saved keyframes1/22\keyframe_1_frame20.jpg
# Saved keyframes1/22\keyframe_2_frame50.jpg
# Saved keyframes1/22\keyframe_3_frame80.jpg
# Saved keyframes1/22\keyframe_4_frame110.jpg
# Saved keyframes1/22\keyframe_5_frame130.jpg
# Saved indices to keyframes1/22\22.txt
# Processing Statue of Liberty.mp4...
# Saved keyframes1/23\keyframe_1_frame20.jpg
# Saved keyframes1/23\keyframe_2_frame40.jpg
# Saved keyframes1/23\keyframe_3_frame60.jpg
# Saved keyframes1/23\keyframe_4_frame90.jpg
# Saved keyframes1/23\keyframe_5_frame130.jpg
# Saved keyframes1/23\keyframe_6_frame170.jpg
# Saved keyframes1/23\keyframe_7_frame190.jpg
# Saved keyframes1/23\keyframe_8_frame240.jpg
# Saved keyframes1/23\keyframe_9_frame260.jpg
# Saved keyframes1/23\keyframe_10_frame280.jpg
# Saved keyframes1/23\keyframe_11_frame320.jpg
# Saved keyframes1/23\keyframe_12_frame350.jpg
# Saved indices to keyframes1/23\23.txt
# Processing Uncut_Evening_Flight.mp4...
# Saved keyframes1/24\keyframe_1_frame20.jpg
# Saved keyframes1/24\keyframe_2_frame40.jpg
# Saved keyframes1/24\keyframe_3_frame60.jpg
# Saved keyframes1/24\keyframe_4_frame100.jpg
# Saved keyframes1/24\keyframe_5_frame120.jpg
# Saved keyframes1/24\keyframe_6_frame180.jpg
# Saved keyframes1/24\keyframe_7_frame200.jpg
# Saved keyframes1/24\keyframe_8_frame230.jpg
# Saved keyframes1/24\keyframe_9_frame270.jpg
# Saved keyframes1/24\keyframe_10_frame290.jpg
# Saved keyframes1/24\keyframe_11_frame330.jpg
# Saved keyframes1/24\keyframe_12_frame360.jpg
# Saved keyframes1/24\keyframe_13_frame400.jpg
# Saved keyframes1/24\keyframe_14_frame420.jpg
# Saved keyframes1/24\keyframe_15_frame450.jpg
# Saved keyframes1/24\keyframe_16_frame480.jpg
# Saved keyframes1/24\keyframe_17_frame500.jpg
# Saved keyframes1/24\keyframe_18_frame520.jpg
# Saved keyframes1/24\keyframe_19_frame550.jpg
# Saved keyframes1/24\keyframe_20_frame590.jpg
# Saved keyframes1/24\keyframe_21_frame630.jpg
# Saved keyframes1/24\keyframe_22_frame680.jpg
# Saved keyframes1/24\keyframe_23_frame740.jpg
# Saved keyframes1/24\keyframe_24_frame760.jpg
# Saved keyframes1/24\keyframe_25_frame790.jpg
# Saved keyframes1/24\keyframe_26_frame850.jpg
# Saved keyframes1/24\keyframe_27_frame870.jpg
# Saved keyframes1/24\keyframe_28_frame890.jpg
# Saved keyframes1/24\keyframe_29_frame910.jpg
# Saved keyframes1/24\keyframe_30_frame940.jpg
# Saved indices to keyframes1/24\24.txt
# Processing Valparaiso_Downhill.mp4...
# Saved keyframes1/25\keyframe_1_frame20.jpg
# Saved keyframes1/25\keyframe_2_frame50.jpg
# Saved keyframes1/25\keyframe_3_frame80.jpg
# Saved keyframes1/25\keyframe_4_frame130.jpg
# Saved keyframes1/25\keyframe_5_frame170.jpg
# Saved keyframes1/25\keyframe_6_frame200.jpg
# Saved keyframes1/25\keyframe_7_frame250.jpg
# Saved keyframes1/25\keyframe_8_frame310.jpg
# Saved keyframes1/25\keyframe_9_frame340.jpg
# Saved keyframes1/25\keyframe_10_frame380.jpg
# Saved keyframes1/25\keyframe_11_frame400.jpg
# Saved keyframes1/25\keyframe_12_frame450.jpg
# Saved keyframes1/25\keyframe_13_frame480.jpg
# Saved indices to keyframes1/25\25.txt
